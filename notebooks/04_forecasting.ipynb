# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import joblib

df = pd.read_csv("../data/final_data.csv")
df['Date'] = pd.to_datetime(df['Date'])

# Aggregate daily sales
daily_sales = df.groupby('Date')['Revenue'].sum()

# Fit ARIMA model
model = ARIMA(daily_sales, order=(5,1,0))
model_fit = model.fit()

# Save model
joblib.dump(model_fit, "../models/sales_forecast_model.pkl")

# Forecast next 30 days
forecast = model_fit.forecast(steps=30)

forecast.plot(title="Next 30 Days Sales Forecast")
plt.show()
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# c:\Users\dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
